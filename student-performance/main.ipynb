# %%
# %pip install kagglehub numpy scipy scikit-learn pandas matplotlib
# Out:
# Collecting kagglehub
#   Using cached kagglehub-0.3.12-py3-none-any.whl (67 kB)
# Collecting numpy
#   Downloading numpy-2.2.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 9.3 MB/s eta 0:00:0000:01:00:01
# Collecting scipy
#   Using cached scipy-1.15.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.6 MB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
# Collecting pandas
#   Using cached pandas-2.2.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.1 MB)
# Collecting matplotlib
#   Using cached matplotlib-3.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Collecting pyyaml
#   Using cached PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
# Requirement already satisfied: packaging in /home/squirrelcoding/Code/datascience/env/lib/python3.10/site-packages (from kagglehub) (25.0)
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting threadpoolctl>=3.1.0
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Collecting joblib>=1.2.0
#   Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Collecting tzdata>=2022.7
#   Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/squirrelcoding/Code/datascience/env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.57.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
# Collecting pillow>=8
#   Using cached pillow-11.2.1-cp310-cp310-manylinux_2_28_x86_64.whl (4.6 MB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Requirement already satisfied: six>=1.5 in /home/squirrelcoding/Code/datascience/env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.7/128.7 KB 11.3 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.6/159.6 KB 4.5 MB/s eta 0:00:00
# Collecting idna<4,>=2.5
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (146 kB)
# Installing collected packages: pytz, urllib3, tzdata, tqdm, threadpoolctl, pyyaml, pyparsing, pillow, numpy, kiwisolver, joblib, idna, fonttools, cycler, charset-normalizer, certifi, scipy, requests, pandas, contourpy, scikit-learn, matplotlib, kagglehub
# Successfully installed certifi-2025.4.26 charset-normalizer-3.4.1 contourpy-1.3.2 cycler-0.12.1 fonttools-4.57.0 idna-3.10 joblib-1.4.2 kagglehub-0.3.12 kiwisolver-1.4.8 matplotlib-3.10.1 numpy-2.2.5 pandas-2.2.3 pillow-11.2.1 pyparsing-3.2.3 pytz-2025.2 pyyaml-6.0.2 requests-2.32.3 scikit-learn-1.6.1 scipy-1.15.2 threadpoolctl-3.6.0 tqdm-4.67.1 tzdata-2025.2 urllib3-2.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import kagglehub
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Download latest version
path = kagglehub.dataset_download("joshuanaude/effects-of-alcohol-on-student-performance", path="Stats survey.csv")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: /home/squirrelcoding/.cache/kagglehub/datasets/joshuanaude/effects-of-alcohol-on-student-performance/versions/1/Stats survey.csv

# %%
df = pd.read_csv(path)

df.head()
# Out:
#                    Timestamp Your Sex?  \
# 0  2024/03/07 5:12:01 pm EET    Female
# 1  2024/03/07 5:12:08 pm EET      Male
# 2  2024/03/07 5:12:25 pm EET      Male
# 3  2024/03/07 5:12:28 pm EET      Male
# 4  2024/03/07 5:13:00 pm EET    Female
#
#    Your Matric (grade 12) Average/ GPA (in %)  \
# 0                                        76.0
# 1                                        89.0
# 2                                        76.0
# 3                                        89.0
# 4                                        74.0
#
#   What year were you in last year (2023) ?  \
# 0                                 2nd Year
# 1                                 2nd Year
# 2                                 1st Year
# 3                                 2nd Year
# 4                                 2nd Year
#
#   What faculty does your degree fall under?  \
# 0                    Arts & Social Sciences
# 1            Economic & Management Sciences
# 2                              AgriSciences
# 3                               Engineering
# 4                    Arts & Social Sciences
#
#    Your 2023 academic year average/GPA in % (Ignore if you are 2024 1st year student)  \
# 0                                               72.0
# 1                                               75.0
# 2                                               55.0
# 3                                               84.0
# 4                                               52.0
#
#         Your Accommodation Status Last Year (2023) Monthly Allowance in 2023  \
# 0  Private accommodation/ stay with family/friends            R 4001- R 5000
# 1  Private accommodation/ stay with family/friends           R 7001 - R 8000
# 2  Private accommodation/ stay with family/friends            R 4001- R 5000
# 3  Private accommodation/ stay with family/friends           R 6001 - R 7000
# 4  Private accommodation/ stay with family/friends            R 4001- R 5000
#
#   Were you on scholarship/bursary in 2023?  \
# 0                                       No
# 1                      Yes (NSFAS, etc...)
# 2                                       No
# 3                                       No
# 4                                       No
#
#   Additional amount of studying (in hrs) per week  \
# 0                                              8+
# 1                                              8+
# 2                                             3-5
# 3                                             3-5
# 4                                             3-5
#
#   How often do you go out partying/socialising during the week?   \
# 0                                      Only weekends
# 1                                      Only weekends
# 2                                                  2
# 3                                                  3
# 4                                      Only weekends
#
#   On a night out, how many alcoholic drinks do you consume?  \
# 0                                                 8+
# 1                                                3-5
# 2                                                 8+
# 3                                                 8+
# 4                                                5-8
#
#   How many classes do you miss per week due to alcohol reasons, (i.e: being hungover or too tired?)  \
# 0                                                  3
# 1                                                 4+
# 2                                                  3
# 3                                                  2
# 4                                                  1
#
#   How many modules have you failed thus far into your studies?  \
# 0                                                  0
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  3
#
#   Are you currently in a romantic relationship?  \
# 0                                           Yes
# 1                                            No
# 2                                            No
# 3                                           Yes
# 4                                            No
#
#   Do your parents approve alcohol consumption?  \
# 0                                          Yes
# 1                                          Yes
# 2                                          Yes
# 3                                          Yes
# 4                                          Yes
#
#   How strong is your relationship with your parent/s?
# 0                                         Very close
# 1                                         Very close
# 2                                         Very close
# 3                                         Very close
# 4                                               Fair
